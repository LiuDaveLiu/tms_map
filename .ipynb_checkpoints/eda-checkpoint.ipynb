# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#import nessus_report # python 2 script

# %%
base_dir='C:/Users/lliu10/OneDrive - Inside MD Anderson/Documents/Text Exports for Low Grade Glioma 1.21-8.22/'

# %%
a=open('test.nbe')

# %%
csv_base='C:/Users/lliu10/OneDrive - Inside MD Anderson/Documents/Example_Data_v1.9.1.27b/Stimulation_data/xlsx/'

# %%
csv_data=pd.read_csv(csv_base+'New subject 02_New session 04_MAIN_Ch1_Smoothly_cut_Flat_2DColorMap.csv', sep=';')

# %%
max_x=max(csv_data['i'])+1
max_y=max(csv_data['j'])+1
Z=np.zeros((max_x,max_y))
for i in range(len(csv_data)):
    Z[csv_data['i'][i],csv_data['j'][i]]=csv_data['amp'][i]

# %%
x_edge=360
y_edge=460
fig, ax = plt.subplots()
cs=ax.contourf(np.arange(0,x_edge,x_edge/max_x), np.arange(0,y_edge,y_edge/(max_y-1)), Z, 20, cmap='RdGy')
ax.set_aspect("equal")
ax.xaxis.set_minor_locator(MultipleLocator(10))
ax.yaxis.set_minor_locator(MultipleLocator(10))
plt.xlabel('mm')
plt.ylabel('mm')
cbar=fig.colorbar(cs,ticks=[0,200, 400])
cbar.set_label(u'MEP Amplitude (\u03bcV)')
plt.savefig("output.pdf", transparent=True)

# %%
max_x
# Out:
# 101
